# %%
import pandas as pd
df = pd.DataFrame(pd.read_excel("eğitim durumuna göre hüküm giyenler.xls"))

# %%
my_cols = ["","Total", "Total - Male", "Total - Female", "Illiterate Male", "Illiterate Female", "Literate but Not Graduated From a School Male", "Literate but Not Graduated From a School Female", "Primary School Male", "Primary School Female", "Primary Education Male", "Primary Education Female","Junior High School Level Male", "Junior High School Level Female","High School Level Male", "High School Level Female", "Higher Education Male", "Higher Education Female", "Unkown Male", "Unknown Female"]

# %%
df = df.iloc[17:-4].reset_index(drop = True)
for column in df.columns:
    if df[column].isnull().all():
        df = df.drop(columns=column)
for index, row in df.iterrows():
    if pd.isnull(row).all():
        df.drop(index=index, inplace=True)
        df = df.reset_index(drop = True)
df.columns = my_cols

# %%
holder1 = {}
holder1[2020] = df.iloc[1:41]
holder1[2019] = df.iloc[42:82]
holder1[2018] = df.iloc[84:123]
new_row = ["Toplam - Total", 266889, 256753, 10136, 1421, 399, 10673, 1101, 41779, 2096, 95564, 2576, 35854, 1026, 55962, 1895, 13057, 857, 2443, 186]
new_row_df = pd.DataFrame([new_row], columns=my_cols)
holder1[2018] = pd.concat([new_row_df,holder1[2018]]).reset_index(drop=True)
holder1[2017] = df.iloc[126:163]
new_row = ["Toplam - Total", 215761, 207475, 8286, 1223, 356, 10918, 1080, 39784, 1971, 76155, 2007, 24237, 724, 44057, 1451, 9293, 564, 1808, 133]
new_row_df = pd.DataFrame([new_row], columns=my_cols)
holder1[2017] = pd.concat([new_row_df,holder1[2017]]).reset_index(drop=True)
holder1[2016] = df.iloc[166:203]
holder1[2015] = df.iloc[206:243]
holder1[2014] = df.iloc[246:283]
holder1[2013] = df.iloc[286:323]
holder1[2012] = df.iloc[326:359]
holder1[2011] = df.iloc[362:]

# %%
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes", "Unknown"]

# %%
for hold in holder1:
    rows_to_drop = []
    for index, row in holder1[hold].iterrows():
        if row.isna().any():
            rows_to_drop.append(index)
    holder1[hold] = holder1[hold].drop(rows_to_drop)
    holder1[hold] = holder1[hold].replace('-', 0)
    for column in holder1[hold].columns.tolist()[1:]:
        holder1[hold][column] = holder1[hold][column].astype(int)
    holder1[hold] = holder1[hold].reset_index(drop = True)

# %%
holder1[2020].index = new_row_labels
holder1[2019].index = new_row_labels
holder1[2018].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder1[2017].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder1[2016].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder1[2015].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Theft", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder1[2014].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping","Defamation", "Theft", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder1[2013].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping","Defamation", "Theft", "Robbery","Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Other Crimes"]
holder1[2012].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping","Defamation", "Theft", "Robbery","Opposition to cheque laws","Swindling", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Other Crimes"]
holder1[2011].index = new_row_labels

for hold in holder1:
    holder1[hold] = holder1[hold].drop('', axis = 1)

# %%
df = pd.DataFrame(pd.read_excel("eğitime göre çıkanlar.xls"))

# %%
df = df.iloc[13:-4].reset_index(drop = True)
for column in df.columns:
    if df[column].isnull().all():
        df = df.drop(columns=column)
for index, row in df.iterrows():
    if pd.isnull(row).all():
        df.drop(index=index, inplace=True)
        df = df.reset_index(drop = True)
df.columns = my_cols

# %%
holder0 = {}
holder0[2020] = df.iloc[1:34]
holder0[2019] = df.iloc[50:82]
new_row = ["Toplam",291212,280013,11199	,1561,466,9989,1081	,42120,2134	,58136,1615,84160,2394,64773,2232,15687,1101,3587,176]
new_row_df = pd.DataFrame([new_row], columns=my_cols)
holder0[2019] = pd.concat([new_row_df,holder0[2019]]).reset_index(drop=True)
holder0[2018] = df.iloc[98:130]
holder0[2017] = df.iloc[146:177]
holder0[2016] = df.iloc[194:224]
holder0[2015] = df.iloc[241:271]
holder0[2014] = df.iloc[288:318]
holder0[2013] = df.iloc[335:365]
holder0[2012] = df.iloc[382:408]
holder0[2011] = df.iloc[425:]

# %%
for hold in holder0:
    rows_to_drop = []
    for index, row in holder0[hold].iterrows():
        if row.isna().any():
            rows_to_drop.append(index)
    holder0[hold] = holder0[hold].drop(rows_to_drop)
    holder0[hold] = holder0[hold].replace('-', 0)
    for column in holder0[hold].columns.tolist()[1:]:
        holder0[hold][column] = holder0[hold][column].astype(int)
    holder0[hold] = holder0[hold].reset_index(drop = True)

# %%
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes","Unknown"]
holder0[2020].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder0[2019].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Sexual Crimes", "Kidnapping", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes","Unknown"]
holder0[2018].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault","Sexual Crimes", "Defamation", "Theft", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Preotection", "Other Crimes"]
holder0[2017].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault","Kidnapping", "Defamation", "Robbery", "Swindling", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Protection", "Other Crimes"]
holder0[2016].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Theft", "Robbery", "Production and commerce of drugs", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Protection", "Other Crimes"]
holder0[2015].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation","Theft", "Swindling", "Use and purchase of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Protection", "Other Crimes"]
holder0[2014].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation","Theft","Robbery", "Swindling", "Production and commerce of drugs", "Forgery", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Threat", "Damage to Property", "Prevention of Performance", "Contrary to the Measures For Family Protection", "Other Crimes"]
holder0[2013].index = new_row_labels
new_row_labels = ["Total", "Homicide", "Assault", "Sexual Crimes", "Kidnapping", "Defamation","Theft","Robbery", "Opposition to cheque laws","Swindling", "Use and purchase of drugs", "Bad Treatment", "Embezzlement", "Bribery", "Smuggling", "Traffic Crimes", "Forestry Crimes", "Crimes related with firearms and knifes", "Opposition to the Bankruptcy and Enforcement Law", "Opposition to the Military Criminal Law", "Other Crimes"]
holder0[2012].index = new_row_labels
holder0[2011].index = new_row_labels
for hold in holder0:
    holder0[hold] = holder0[hold].drop('', axis = 1)

# %%
holder1[2013]
# Out:
#                                                    Total  Total - Male
# Total                                             161711        156184  \
# Homicide                                            6534          6382
# Assault                                            29818         29180
# Sexual Crimes                                       4143          4078
# Kidnapping                                          2383          2310
# Defamation                                          3676          3515
# Theft                                              22343         20876
# Swindling                                           2463          2328
# Production and commerce of drugs                    9177          8849
# Use and purchase of drugs                           2674          2629
# Forgery                                             6492          6280
# Bad Treatment                                         98            90
# ...

# %%
holder = {0: holder0, 1: holder1}
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
holder_names = ["egitimegorecıkanlar", "egitimegorehukumgiyenler"]

# %%
years = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
from database import Database
db = Database()

# %%
unsuccesful_insertions = []
succesful_insertions = []
if db.try_to_connect():
    for hold in holder:
        for year in years:
            print("Hold:", hold)
            print("Year:",year)
            dataframe = holder[hold][year] 
            name = holder_names[hold] + str(str(year)[2:])
            print("Table name:", name)
            try:
                db.create_table(table_name=name, df= dataframe)
            except: 
                pass
            
            if db.insert_data(name,dataframe):
                succesful_insertions.append(name)
                print("*****************************")
            else:
                print(f"Unsuccesful insertion of creating {name} table")
                unsuccesful_insertions.append(name)
                print("*****************************")
                
if len(unsuccesful_insertions) == 0:
    print("No unsuccesful insertions :)")
else:
    print("Unsuccesful insertions are available")
    for insertion in unsuccesful_insertions:
        print(f"Table name: {insertion}")
# Out:
# Connected to the database.
# Hold: 0
# Year: 2011
# Table name: egitimegorecıkanlar11
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2012
# Table name: egitimegorecıkanlar12
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2013
# Table name: egitimegorecıkanlar13
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2014
# Table name: egitimegorecıkanlar14
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2015
# Table name: egitimegorecıkanlar15
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2016
# Table name: egitimegorecıkanlar16
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2017
# Table name: egitimegorecıkanlar17
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2018
# Table name: egitimegorecıkanlar18
# Succesful insertion
# *****************************
# Hold: 0
# Year: 2019
# Table name: egitimegorecıkanlar19
# ...
